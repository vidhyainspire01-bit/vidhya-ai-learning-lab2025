# %%
import pandas as pd
dataset=pd.read_csv("preplacement.csv")
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt  
from scipy.stats import norm
def check_distribution(dataset,startrange,endrange):
# Histogram (green) + KDE (blue)
    plt.figure(figsize=(7,4))
    ax=sns.histplot(dataset, kde=True, stat="density", bins=30, color="skyblue")
    sns.kdeplot(dataset, color='blue', ax=ax)
    
    # Vertical lines
    plt.axvline(startrange, color='red', linestyle="-")
    plt.axvline(endrange, color='red', linestyle="-")
    
    dataset_mean=dataset.mean()
    dataset_std=dataset.std()
    
    print("Mean=%.3f,Standard Deviation=%.3f" %(dataset_mean,dataset_std))
    dist=norm(dataset_mean,dataset_std)
    
    values=[value for value in range(startrange,endrange)]
           
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return float(prob)

# %%
check_distribution(dataset["hsc_p"],60,70)
# Out:
# Mean=66.333,Standard Deviation=10.898
# The area between range(60,70):0.34911643265441233
# 0.34911643265441233

# %%
import seaborn as sns
import matplotlib.pyplot as plt  
from scipy.stats import norm
def check_distribution(dataset,startrange,endrange):
# Histogram (green) + KDE (blue)
    plt.figure(figsize=(7,4))
    ax=sns.histplot(dataset, kde=True, stat="density", bins=30, color="green")
    sns.kdeplot(dataset, color='blue', ax=ax)
    
    # Vertical lines
    plt.axvline(startrange, color='red', linestyle="-")
    plt.axvline(endrange, color='red', linestyle="-")
    
    dataset_mean=dataset.mean()
    dataset_std=dataset.std()
    
    print("Mean=%.3f,Standard Deviation=%.3f" %(dataset_mean,dataset_std))
    dist=norm(dataset_mean,dataset_std)
    
    values=[]
    for value in range(startrange,endrange):
       values.append(value)
    
   #values=[value for value in range(startrange,endrange)
           
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return float(prob)

# %%
check_distribution(dataset["hsc_p"],60,90)
# Out:
# Mean=66.333,Standard Deviation=10.898
# The area between range(60,90):0.7180298788589667
# 0.7180298788589667

# %%
check_distribution(dataset["ssc_p"],60,80)
# Out:
# Mean=67.303,Standard Deviation=10.827
# The area between range(60,80):0.6346413295441957
# 0.6346413295441957

# %%
#cumulative normal distribution
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset['ssc_p'])
float(ecdf(70))
# Out:
# 0.6093023255813953

# %%
df=dataset
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

def check_distribution_column(series, lower=60, upper=70):
    """Check distribution for a specific column (P between lower–upper)."""
    data = pd.to_numeric(series, errors="coerce").dropna()
    mu, sigma = data.mean(), data.std()

    # Probability from Normal Distribution
    prob = norm.cdf(upper, mu, sigma) - norm.cdf(lower, mu, sigma)

    # Empirical proportion (actual data between range)
    emp = ((data >= lower) & (data <= upper)).mean()

    # Plot distribution with shaded area
    plt.figure(figsize=(7,4))
    sns.histplot(data, kde=True, stat="density", color="skyblue", bins=30)

    # Shade the region
    x = np.linspace(data.min(), data.max(), 200)
    y = norm.pdf(x, mu, sigma)
    mask = (x >= lower) & (x <= upper)
    plt.fill_between(x[mask], y[mask], 0, alpha=0.3, color="blue")

    plt.axvline(lower, color="red", linestyle="--")
    plt.axvline(upper, color="red", linestyle="--")
    plt.title(f"Distribution of Column | Normal P={prob:.3f}, Empirical={emp:.3f}")
    plt.show()

    return {"Mean": mu, "Std": sigma, "NormalProb": prob, "EmpiricalProb": emp}
df = pd.read_csv("preplacement.csv")

# Pass only one column
result = check_distribution_column(df["ssc_p"], 60, 70)
print(result)
# Out:
# {'Mean': np.float64(67.30339534883721), 'Std': np.float64(10.827205398231452), 'NormalProb': np.float64(0.34835845838786206), 'EmpiricalProb': np.float64(0.3767441860465116)}

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

def check_distribution_column(series, lower=60, upper=70):
    """Check distribution for a specific column (P between lower–upper)."""
    data = pd.to_numeric(series, errors="coerce").dropna()
    mu, sigma = data.mean(), data.std()

    # Probability from Normal Distribution
    prob = norm.cdf(upper, mu, sigma) - norm.cdf(lower, mu, sigma)

    # Empirical proportion (actual data between range)
    emp = ((data >= lower) & (data <= upper)).mean()

    # Plot distribution with shaded area
    plt.figure(figsize=(7,4))
    sns.histplot(data, kde=True, stat="density", color="skyblue", bins=30)

    # Shade the region
    x = np.linspace(data.min(), data.max(), 200)
    y = norm.pdf(x, mu, sigma)
    mask = (x >= lower) & (x <= upper)
    plt.fill_between(x[mask], y[mask], 0, alpha=0.3, color="blue")

    plt.axvline(lower, color="red", linestyle="-")
    plt.axvline(upper, color="red", linestyle="-")
    plt.title(f"Distribution | Normal P={prob:.3f}, Empirical={emp:.3f}")
    plt.show()

    # Convert to native Python floats
    return {
        "Mean": float(mu),
        "Std": float(sigma),
        "NormalProb": float(prob),
        "EmpiricalProb": float(emp)
    }
df = pd.read_csv("preplacement.csv")

result = check_distribution_column(df["ssc_p"], 50, 70)
print(result)
# Out:
# {'Mean': 67.30339534883721, 'Std': 10.827205398231452, 'NormalProb': 0.5433362747878877, 'EmpiricalProb': 0.5581395348837209}

# %%
ax=sns.histplot(data, kde=True, stat="density", color="skyblue", bins=30)
